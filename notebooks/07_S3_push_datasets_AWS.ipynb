# %%
import boto3
from pathlib import Path

# ---- Config ----
bucket = "housing-regression-data"   # replace with your bucket name
region = "us-east-1"                 # your AWS region

# Set project root as parent of the notebooks folder
PROJECT_ROOT = Path.cwd().parent
local_data_dir = PROJECT_ROOT / "data" / "processed"
local_model_dir = PROJECT_ROOT / "models"

s3 = boto3.client("s3", region_name=region)

# ---- Helper function ----
def upload_file(local_path: Path, s3_key: str):
    if not local_path.exists():
        print(f"❌ File not found: {local_path}")
        return
    print(f"⬆️ Uploading {local_path} → s3://{bucket}/{s3_key}")
    s3.upload_file(str(local_path), bucket, s3_key)

# ---- Upload required datasets ----
upload_file(local_data_dir / "feature_engineered_holdout.csv", "processed/feature_engineered_holdout.csv")
upload_file(local_data_dir / "cleaning_holdout.csv", "processed/cleaning_holdout.csv")
upload_file(local_data_dir / "feature_engineered_train.csv", "processed/feature_engineered_train.csv")

# ---- Upload model ----
upload_file(local_model_dir / "xgb_best_model.pkl", "models/xgb_best_model.pkl")
# Out:
# ❌ File not found: c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\data\processed\feature_engineered_holdout.csv
# ❌ File not found: c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\data\processed\cleaning_holdout.csv
# ⬆️ Uploading c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\data\processed\feature_engineered_train.csv → s3://housing-regression-data/processed/feature_engineered_train.csv
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\boto3\s3\transfer.py:373, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     372 try:
# --> 373     future.result()
#     374 # If a client error was raised, add the backwards compatibility layer
#     375 # that raises a S3UploadFailedError. These specific errors were only
#     376 # ever thrown for upload_parts but now can be thrown for any related
#     377 # client error.
#
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\s3transfer\futures.py:111, in TransferFuture.result(self)
#     107 try:
#     108     # Usually the result() method blocks until the transfer is done,
#     109     # however if a KeyboardInterrupt is raised we want want to exit
#     110     # out of this and propagate the exception.
# --> 111     return self._coordinator.result()
#     112 except KeyboardInterrupt as e:
#
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\s3transfer\futures.py:287, in TransferCoordinator.result(self)
#     286 if self._exception:
# --> 287     raise self._exception
#     288 return self._result
#
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\s3transfer\tasks.py:142, in Task.__call__(self, ctx)
#     141     if not self._transfer_coordinator.done():
# --> 142         return self._execute_main(kwargs)
#     143 except Exception as e:
#
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\s3transfer\tasks.py:165, in Task._execute_main(self, kwargs)
#     163 logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")
# --> 165 return_value = self._main(**kwargs)
#     166 # If the task is the final task, then set the TransferFuture's
#     167 # value to the return value from main().
#
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\s3transfer\tasks.py:351, in CreateMultipartUploadTask._main(self, client, bucket, key, extra_args)
#     350 # Create the multipart upload.
# --> 351 response = client.create_multipart_upload(
#     352     Bucket=bucket, Key=key, **extra_args
#     353 )
#     354 upload_id = response['UploadId']
#
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\botocore\client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#
# ClientError: An error occurred (AccessDenied) when calling the CreateMultipartUpload operation: Access Denied
#
# During handling of the above exception, another exception occurred:
#
# S3UploadFailedError                       Traceback (most recent call last)
# Cell In[2], line 26
#      24 upload_file(local_data_dir / "feature_engineered_holdout.csv", "processed/feature_engineered_holdout.csv")
#      25 upload_file(local_data_dir / "cleaning_holdout.csv", "processed/cleaning_holdout.csv")
# ---> 26 upload_file(local_data_dir / "feature_engineered_train.csv", "processed/feature_engineered_train.csv")
#      28 # ---- Upload model ----
#      29 upload_file(local_model_dir / "xgb_best_model.pkl", "models/xgb_best_model.pkl")
#
# Cell In[2], line 21, in upload_file(local_path, s3_key)
#      19     return
#      20 print(f"⬆️ Uploading {local_path} → s3://{bucket}/{s3_key}")
# ---> 21 s3.upload_file(str(local_path), bucket, s3_key)
#
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\boto3\s3\inject.py:175, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     140 """Upload a file to an S3 object.
#     141
#     142 Usage::
#    (...)    172     transfer.
#     173 """
#     174 with S3Transfer(self, Config) as transfer:
# --> 175     return transfer.upload_file(
#     176         filename=Filename,
#     177         bucket=Bucket,
#     178         key=Key,
#     179         extra_args=ExtraArgs,
#     180         callback=Callback,
#     181     )
#
# File c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\boto3\s3\transfer.py:379, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     374 # If a client error was raised, add the backwards compatibility layer
#     375 # that raises a S3UploadFailedError. These specific errors were only
#     376 # ever thrown for upload_parts but now can be thrown for any related
#     377 # client error.
#     378 except ClientError as e:
# --> 379     raise S3UploadFailedError(
#     380         "Failed to upload {} to {}: {}".format(
#     381             filename, '/'.join([bucket, key]), e
#     382         )
#     383     )
#
# S3UploadFailedError: Failed to upload c:\Users\Ar\Desktop\Regression_ML_EndtoEnd\data\processed\feature_engineered_train.csv to housing-regression-data/processed/feature_engineered_train.csv: An error occurred (AccessDenied) when calling the CreateMultipartUpload operation: Access Denied
